# %%
path = '../data/players.json'
import pandas as pd
import json

# %%
with open(path) as f:
    
    data = json.load(f)
    
df = pd.json_normalize(data)

df.head()
# Out:
#          tier                              leagueId            queue  \
# 0  CHALLENGER  c9c33ae0-81ab-3e14-bbec-00b1d071e980  RANKED_SOLO_5x5
#
#                 name                                            entries
# 0  Trundle's Tyrants  [{'puuid': '3AkFV2E2Km8vWJ0-G7loWKaIEq3PDHQlLt...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   tier      1 non-null      str
#  1   leagueId  1 non-null      str
#  2   queue     1 non-null      str
#  3   name      1 non-null      str
#  4   entries   1 non-null      object
# dtypes: object(1), str(4)
# memory usage: 172.0+ bytes
